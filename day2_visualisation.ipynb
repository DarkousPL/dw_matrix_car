# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd "/content/drive/My Drive/Colab Notebooks/matrix/matrix_two/dw_matrix_car"
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_two/dw_matrix_car

# %%
ls
# Out:
# data/  LICENSE  README.md

# %%
ls data/car.h5
# Out:
# data/car.h5

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %%
df.columns.values

# %%
df['price_value'].hist(bins=100)

# %%
df['price_value'].describe()
# Out:
# count    106494.000000
# mean      47534.137437
# std       66308.716918
# min         400.000000
# 25%       13890.000000
# 50%       25500.000000
# 75%       52900.000000
# max      799900.000000
# Name: price_value, dtype: float64

# %%
(
df
 .groupby('param_marka-pojazdu')['price_value']
 .agg([np.mean, np.median, np.size])
 .sort_values(by ='size', ascending=False)
 .head(50)
).plot(kind='bar', figsize=(25, 10), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9046da4940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f90467c1f98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f9046781438>],
#       dtype=object)

# %%
def group_and_barplot(feat_groupby, feat_agg='price_value', agg_funcs=[np.mean, np.median, np.size], feat_sort='mean', top=50, subplots=True):
  return (
      df
      .groupby(feat_groupby)[feat_agg]
      .agg(agg_funcs)
      .sort_values(by=feat_sort, ascending=False)
      .head(top)
  ).plot(kind='bar', figsize=(25, 5), subplots=subplots)

# %%
group_and_barplot('param_marka-pojazdu');

# %%
group_and_barplot('param_kolor', feat_sort='mean');

# %%
group_and_barplot('param_kraj-pochodzenia', feat_sort='size');
